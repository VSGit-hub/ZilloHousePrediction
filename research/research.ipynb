# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Vaibhav\\Desktop\\Course\\Projecs\\01_ZillowHousePrice_Regression\\research'

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\Vaibhav\\Desktop\\Course\\Projecs\\01_ZillowHousePrice_Regression'

# %%
data = pd.read_excel('raw_data/ZilloHousePriceData.xlsx')
data.head()
# Out:
#                                   contact_recipients  longitude  countyFIPS  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -149.90807      2020.0
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -149.90822      2020.0
# 2  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -149.90833      2020.0
# 3                                                 {}        NaN         NaN
# 4  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -149.90834      2020.0
#
#                                               imgSrc  livingAreaValue  \
# 0  https://photos.zillowstatic.com/fp/ce047439c86...           2668.0
# 1  https://maps.googleapis.com/maps/api/streetvie...           3179.0
# 2  https://maps.googleapis.com/maps/api/streetvie...           3059.0
# 3                                                NaN              NaN
# 4  https://photos.zillowstatic.com/fp/10602cde74a...           1642.0
#
#   streetAddress             county  monthlyHoaFee           timeZone  \
# ...

# %%
data.describe()
# Out:
#          longitude    countyFIPS  livingAreaValue  monthlyHoaFee  \
# count  6042.000000   5896.000000      5869.000000    1161.000000
# mean   -145.749918   3232.119742      1795.795025     287.714040
# std      15.835762   6468.792955      1532.936783    1352.210988
# min    -158.757920   1031.000000         0.000000       4.000000
# 25%    -149.925387   2020.000000      1141.000000     103.000000
# 50%    -149.859490   2020.000000      1670.000000     271.000000
# 75%    -149.805183   2020.000000      2128.000000     350.000000
# max     -66.049990  56001.000000     95337.000000   45929.000000
#
#        annualHomeownersInsurance    yearBuilt     latitude  rentZestimate  \
# count                7160.000000  5690.000000  6042.000000    6034.000000
# mean                 1211.979888  1976.310545    59.585590    2593.182963
# std                   994.675514    13.387253     6.073109     763.919618
# min                     0.000000  1880.000000    18.073723     693.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7160 entries, 0 to 7159
# Data columns (total 67 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   contact_recipients         7160 non-null   object
#  1   longitude                  6042 non-null   float64
#  2   countyFIPS                 5896 non-null   float64
#  3   imgSrc                     6043 non-null   object
#  4   livingAreaValue            5869 non-null   float64
#  5   streetAddress              6043 non-null   object
#  6   county                     5995 non-null   object
#  7   monthlyHoaFee              1161 non-null   float64
#  8   timeZone                   6043 non-null   object
#  9   taxHistory                 6043 non-null   object
#  10  dateSold                   221 non-null    object
#  11  annualHomeownersInsurance  7160 non-null   int64
#  12  state                      6043 non-null   object
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# contact_recipients
# longitude
# countyFIPS
# imgSrc
# livingAreaValue
# streetAddress
# county
# monthlyHoaFee
# timeZone
# taxHistory
# dateSold
# annualHomeownersInsurance
# state
# listed_by
# yearBuilt
# brokerageName
# description
# latitude
# nearbyHomes
# priceHistory
# schools
# rentZestimate
# city
# providerListingID
# currency
# listingProvider
# zestimateLowPercent
# openHouseSchedule
# mortgageRates
# address
# cityId
# timeOnZillow
# url
# zestimate
# zpid
# countyId
# brokerId
# livingAreaUnits
# comingSoonOnMarketDate
# livingArea
# building
# stateId
# zipcode
# propertyTaxRate
# attributionInfo
# bathrooms
# homeStatus
# homeFacts
# resoFacts
# datePosted
# bedrooms
# propertyTypeDimension
# mortgageZHLRates
# price
# favoriteCount
# isListedByOwner
# zestimateHighPercent
# mlsid
# listingSubType
# pageViewCount
# buildingId
# country
# homeType
# solarPotential
# contingentListingType
# message
# resoFacts.daysOnZillow

# %%
house = data.iloc[0]
cols = ['livingAreaValue', 'monthlyHoaFee', 'timeZone', 'taxHistory', 'annualHomeownersInsurance', 'yearBuilt', 'longitude', 'latitude',
        'nearbyHomes','priceHistory', 'schools', 'rentZestimate', 'currency', 'zestimateLowPercent', 'mortgageRates', 'zestimate',
        'zpid', 'countyId', 'livingAreaUnits', 'livingArea', 'building', 'stateId', 'zipcode', 'propertyTaxRate', 'bathrooms', 'bedrooms',
        'propertyTypeDimension', 'mortgageZHLRates', 'price', 'homeType', 'solarPotential', 'contingentListingType']

for param in cols:
    print(param,": ",house[param])
# Out:
# livingAreaValue :  2668.0
# monthlyHoaFee :  nan
# timeZone :  America/Anchorage
# ...

# %%
filtered_data = ['livingAreaValue', 'annualHomeownersInsurance', 'yearBuilt', 'rentZestimate', 'zestimateLowPercent', 'countyId', 'livingArea',
                 'stateId', 'zipcode', 'propertyTaxRate', 'bathrooms', 'bedrooms', 'propertyTypeDimension', 'price']

# %%
data = data[filtered_data]
data.head()
# Out:
#    livingAreaValue  annualHomeownersInsurance  yearBuilt  rentZestimate  \
# 0           2668.0                       2840     1959.0         3142.0
# 1           3179.0                       2934     1961.0         3113.0
# 2           3059.0                       4187     1983.0         4282.0
# 3              NaN                          0        NaN            NaN
# 4           1642.0                       2920     1947.0         3458.0
#
#    zestimateLowPercent  countyId  livingArea  stateId zipcode  \
# 0                 12.0    2616.0      2668.0      3.0   99501
# 1                 12.0    2616.0      3179.0      3.0   99501
# 2                 12.0    2616.0      3059.0      3.0   99501
# 3                  NaN       NaN         NaN      NaN     NaN
# 4                 15.0    2616.0      1642.0      3.0   99501
#
#    propertyTaxRate  bathrooms  bedrooms propertyTypeDimension   price
# 0             1.31        2.0       3.0         Single Family  676100
# ...

# %% [markdown]
# ## Data cleaning

# %%
data.isna().sum()
# Out:
# livingAreaValue              1291
# annualHomeownersInsurance       0
# yearBuilt                    1470
# rentZestimate                1126
# zestimateLowPercent          1498
# countyId                     1117
# livingArea                   1291
# stateId                      1117
# zipcode                      1117
# propertyTaxRate              1125
# bathrooms                    1243
# bedrooms                     1328
# propertyTypeDimension         891
# price                           0
# dtype: int64

# %%
data.shape
# Out:
# (7160, 14)

# %%
data2 = data.dropna()
data2.shape
# Out:
# (5478, 14)

# %%
data2.isna().sum()
# Out:
# livingAreaValue              0
# annualHomeownersInsurance    0
# yearBuilt                    0
# rentZestimate                0
# zestimateLowPercent          0
# countyId                     0
# livingArea                   0
# stateId                      0
# zipcode                      0
# propertyTaxRate              0
# bathrooms                    0
# bedrooms                     0
# propertyTypeDimension        0
# price                        0
# dtype: int64

# %%
data2.head()
# Out:
#    livingAreaValue  annualHomeownersInsurance  yearBuilt  rentZestimate  \
# 0           2668.0                       2840     1959.0         3142.0
# 1           3179.0                       2934     1961.0         3113.0
# 2           3059.0                       4187     1983.0         4282.0
# 4           1642.0                       2920     1947.0         3458.0
# 5           4483.0                       4100     2000.0         4161.0
#
#    zestimateLowPercent  countyId  livingArea  stateId zipcode  \
# 0                 12.0    2616.0      2668.0      3.0   99501
# 1                 12.0    2616.0      3179.0      3.0   99501
# 2                 12.0    2616.0      3059.0      3.0   99501
# 4                 15.0    2616.0      1642.0      3.0   99501
# 5                 18.0    2616.0      4483.0      3.0   99501
#
#    propertyTaxRate  bathrooms  bedrooms propertyTypeDimension   price
# 0             1.31        2.0       3.0         Single Family  676100
# ...

# %%
data.zipcode.unique
# Out:
# <bound method Series.unique of 0       99501
# 1       99501
# 2       99501
# 3         NaN
# 4       99501
#         ...
# 7155    99516
# 7156    99516
# 7157    99507
# 7158    99507
# 7159    99507
# Name: zipcode, Length: 7160, dtype: object>

# %%
#Resetting Index
data2.reset_index(drop=True,inplace=True)
data2
# Out:
#       livingAreaValue  annualHomeownersInsurance  yearBuilt  rentZestimate  \
# 0              2668.0                       2840     1959.0         3142.0
# 1              3179.0                       2934     1961.0         3113.0
# 2              3059.0                       4187     1983.0         4282.0
# 3              1642.0                       2920     1947.0         3458.0
# 4              4483.0                       4100     2000.0         4161.0
# ...               ...                        ...        ...            ...
# 5473           4263.0                       2764     1978.0         3903.0
# 5474           2200.0                       2160     1974.0         3562.0
# 5475           4180.0                       2768     1972.0         4917.0
# 5476           3928.0                       2979     1972.0         4130.0
# 5477           2576.0                       2410     1974.0         3566.0
#
#       zestimateLowPercent  countyId  livingArea  stateId zipcode  \
# ...

# %% [markdown]
# ## EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 5))
plt.scatter(data2.index, data2['zestimateLowPercent'])

# %%
plt.figure(figsize=(12, 5))
plt.bar(data2['propertyTypeDimension'],data2['bathrooms'])
# Out:
# <BarContainer object of 5478 artists>

# %%
plt.figure(figsize=(12, 5))
plt.bar(data2['propertyTypeDimension'],data2['bedrooms'])
# Out:
# <BarContainer object of 5478 artists>

# %%
plt.figure(figsize=(12,5))
plt.bar(data2.propertyTypeDimension.unique(),data2.propertyTypeDimension.value_counts())
# Out:
# <BarContainer object of 8 artists>

# %%
data2.propertyTypeDimension.value_counts()
# Out:
# propertyTypeDimension
# Single Family        3951
# Condo                 815
# Multi Family          472
# Townhouse             173
# Apartment              44
# Manufactured           13
# Lot                     7
# Home Type Unknown       3
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(data2)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data2['propertyTypeDimension']=encoder.fit_transform(data2.propertyTypeDimension)
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_7648\3993376787.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['propertyTypeDimension']=encoder.fit_transform(data2.propertyTypeDimension)

# %%
data2
# Out:
#       livingAreaValue  annualHomeownersInsurance  yearBuilt  rentZestimate  \
# 0              2668.0                       2840     1959.0         3142.0
# 1              3179.0                       2934     1961.0         3113.0
# 2              3059.0                       4187     1983.0         4282.0
# 3              1642.0                       2920     1947.0         3458.0
# 4              4483.0                       4100     2000.0         4161.0
# ...               ...                        ...        ...            ...
# 5473           4263.0                       2764     1978.0         3903.0
# 5474           2200.0                       2160     1974.0         3562.0
# 5475           4180.0                       2768     1972.0         4917.0
# 5476           3928.0                       2979     1972.0         4130.0
# 5477           2576.0                       2410     1974.0         3566.0
#
#       zestimateLowPercent  countyId  livingArea  stateId zipcode  \
# ...

# %%
data2.corr()
# Out:
#                            livingAreaValue  annualHomeownersInsurance  \
# livingAreaValue                   1.000000                   0.678738
# annualHomeownersInsurance         0.678738                   1.000000
# yearBuilt                         0.091041                   0.108587
# rentZestimate                     0.756078                   0.646781
# zestimateLowPercent               0.023463                   0.042510
# countyId                          0.012367                  -0.012794
# livingArea                        1.000000                   0.678738
# stateId                          -0.000522                   0.023189
# zipcode                           0.004432                  -0.042413
# propertyTaxRate                   0.020916                  -0.039812
# bathrooms                         0.742608                   0.475564
# bedrooms                          0.672276                   0.413894
# ...

# %%
sns.heatmap(data2.corr())
# Out:
# <Axes: >

# %%
X = data2.iloc[:, :-1]
y = data2.iloc[:, -1]

# %%
X.shape
# Out:
# (5478, 13)

# %%
y.shape
# Out:
# (5478,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=data2.propertyTypeDimension, random_state=42)

# %%
X_train.shape
# Out:
# (4382, 13)

# %%
X_test.shape
# Out:
# (1096, 13)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)
print(lr.score(X_test, y_test))
# Out:
# 0.9999998971071138

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_pred = lr.predict(X_test)
print("R^2:", lr.score(X_test, y_test))
print("MSE:", mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R^2: 0.9999998971071138
# MSE: 4198.878095511656
# MAE: 53.2440385087421

# %%
from sklearn.ensemble import RandomForestRegressor

reg = RandomForestRegressor(max_depth=3, random_state=4)
reg_model = reg.fit(X_train, y_train)

# %%
pred = reg_model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
print("r2: ", reg_model.score(X_test, y_test))
print('mae: ', mean_absolute_error(y_test, pred))
print('mse: ', mean_squared_error(y_test, pred) )
# Out:
# r2:  0.9796455165328781
# mae:  21512.067529805237
# mse:  830630745.4992603

# %%
from sklearn.linear_model import ElasticNet
eNet = ElasticNet(alpha=0.3, l1_ratio=0.5)
eNet_model=eNet.fit(X_train, y_train)
y_pred=eNet.predict(X_test)
print("r2: ", eNet.score(X_test, y_test))
print('mae: ', mean_absolute_error(y_test, pred))
print('mse: ', mean_squared_error(y_test, pred) )
# Out:
# r2:  0.999999897111733
# mae:  21512.067529805237
# mse:  830630745.4992603

# %%
from sklearn import ensemble
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}
gradBoost = ensemble.GradientBoostingRegressor(**params)
gradBoost_model= gradBoost.fit(X_train, y_train)

# %%
y_pred=gradBoost_model.predict(X_test)
print("r2: ", gradBoost_model.score(X_test, y_test))
print('mae: ', mean_absolute_error(y_test, pred))
print('mse: ', mean_squared_error(y_test, pred) )
# Out:
# r2:  0.9996623665248535
# mae:  21512.067529805237
# mse:  830630745.4992603

# %%
models = {
    "LinearRegression":LinearRegression,
    "RandomForestRegressor": RandomForestRegressor,
    "ElasticNetRegressor":ElasticNet,
}

parameters = {
    "LinearRegression": {
    "fit_intercept": [True, False],
    "positive": [True, False]
    },
   "RandomForestRegressor": {
       "n_estimators":[2,5,10,20],
       "criterion": ['squared_error', 'absolute_error'],
       "max_depth": [3, 5, 8]
   },
   "ElasticNetRegressor": {
       "alpha":[0.2, 0.5],
       "l1_ratio": [0.3, 0.6]
   },
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score

def evaluate_models(X_train, X_test, y_train, y_test, models, params, cv):
    try:
        report = {}
        for model_name in models.keys():
            print("Training",model_name)
            model_class = models[model_name]
            param = params[model_name]
            
            gs = GridSearchCV(model_class(), param, cv=cv)
            gs.fit(X_train, y_train)

            best_model = gs.best_estimator_

            y_train_pred = best_model.predict(X_train)
            y_test_pred = best_model.predict(X_test)

            train_model_score = r2_score(y_train, y_train_pred)
            test_model_score = r2_score(y_test, y_test_pred)

            report[model_name] = test_model_score

        return report
    except Exception as e:
        print("There is some issue", e, e.__traceback__)

# %%
model_report = evaluate_models(X_train, X_test, y_train, y_test, models, parameters, cv=2)
# Out:
# Training LinearRegression
# Training RandomForestRegressor
# Training ElasticNetRegressor

# %%
model_report
# Out:
# {'LinearRegression': 0.9999998973755493,
#  'RandomForestRegressor': 0.9980109752049473,
#  'ElasticNetRegressor': 0.9999998970831077}
